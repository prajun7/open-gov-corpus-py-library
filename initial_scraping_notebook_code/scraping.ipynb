# %% [markdown]
# # Web Scraping

# %% [markdown]
# This is a web scraper for the GOV.UK website, designed to scrape content from various categories and topics from "Services and Information." It uses BeautifulSoup for HTML parsing, requests for HTTP requests, and includes error handling and structured output saving.

# %% [markdown]
# ### Step 0: Load dependencies

# %%
from bs4 import BeautifulSoup
import requests
from html.parser import HTMLParser
import re
import time
import os
from urllib.parse import urljoin
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /rhome/zchapman/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %% [markdown]
# **Imports**:
# - `Beautiful Soup`: also used for parsing HTLML
# - `html.parser`: parser library used by Beautiful Soup
# - `Requests`: used for making http
# - `Pipeline`: used for text generation
# - `nltk`: library for natural language processing
# - `sent_tokenize`: used to split text into sequences
# - `re`: regular expressions

# %% [markdown]
# ### Step 2: Expand the scraper for additional `www.gov.uk` URLs

# %%
BASE_URL = "https://www.gov.uk"
BROWSE_URL = urljoin(BASE_URL, "/browse")
OUTPUT_DIR = "scraped_content" # Directory to save the output files.

# Fetches a URL using a requests.Session object and returns a BeautifulSoup object.
def get_soup(session, url):
    try:
        # Use a try-except block for robust error handling.
        response = session.get(url, timeout=10)  # Add a timeout to prevent hanging.
        response.raise_for_status()  # Raises an HTTPError for bad responses (4xx or 5xx).
        return BeautifulSoup(response.text, "html.parser")
    except requests.exceptions.RequestException as e:
        # Catch any request-related errors (e.g., network issues, timeouts).
        print(f"Error fetching {url}: {e}")
        return None

# Scrapes the main GOV.UK "browse" page to find all top-level category links, returns a list of unique urls for each category.
def get_main_category_links(session):
    print(f"Fetching categories from: {BROWSE_URL}")
    soup = get_soup(session, BROWSE_URL)
    if not soup:
        return []
    # The pattern '/browse/' followed by a name (e.g., '/browse/benefits') has two slashes.
    category_links = {
        urljoin(BASE_URL, link['href'])
        for link in soup.select('main a[href]') # Use a more specific CSS selector
        if link['href'].startswith('/browse/') and link['href'].count('/') == 2
    }
    return sorted(list(category_links)) # Sorting provides a consistent order.

# Scrapes a category page to find all links under the "Topics" section, returns a list of URL, title tuples for each topic. 
def get_topics_from_category(session, category_url):
    soup = get_soup(session, category_url)
    if not soup:
        return []
    topics_heading = soup.find(lambda tag: tag.name in ["h2", "h3"] and "Topics" in tag.get_text())
    if not topics_heading:
        print(f"  -> No 'Topics' section found on {category_url}")
        return []
    topic_list = topics_heading.find_next_sibling("ul")
    if not topic_list:
        return []
    # Return both the link and the text of the link (the sub-topic title).
    topic_links = [
        (urljoin(BASE_URL, link['href']), link.get_text(strip=True))
        for link in topic_list.select('a[href]')
    ]
    return topic_links

# Scrapes a topic landing page to get links to the final content articles, returns a tuple containing a list of URLS and the selector that worked. 
def get_content_links_from_topic(session, topic_url):
    soup = get_soup(session, topic_url)
    if not soup:
        return [], None
    
    # Websites use different structures. We create a list of potential CSS selectors.
    possible_selectors = [
        'main .gem-c-document-list a[href]',      # For pages like 'living-abroad'
        'main .browse-container .govuk-list a[href]', # For pages like 'benefits'
        'main ul.govuk-list a[href]'             # A more general fallback for lists
    ]
    
    link_elements = []
    found_selector = None
    for selector in possible_selectors:
        link_elements = soup.select(selector)
        if link_elements:
            found_selector = selector
            break # If we find links with one selector, we don't need to check the others.

    content_links = [
        urljoin(BASE_URL, link['href'])
        for link in link_elements
        # Ensure we are not re-visiting browse pages.
        if link['href'].startswith('/') and not link['href'].startswith('/browse')
    ]
    return content_links, found_selector

# Scrapes a single final content page for its heading and full body text, returns a dict containing the hedaing and body text. 
def scrape_page_content(session, page_url):
    soup = get_soup(session, page_url)
    if not soup:
        return None
    # Scrape and clean the main body text
    body_text = "No main content found"
    main_content = soup.find('main') # Target the main content area of the page.
    # Remove unwanted elements like the table of contents.
    if main_content:
        toc_classes_to_remove = ['gem-c-contents-list', 'contents', 'toc']
        for toc_class in toc_classes_to_remove:
            for element in main_content.find_all(class_=toc_class):
                element.decompose()
        # Initialize a list to hold the text content from relevant tags.
        content_lines = []
        # Include headers, paragraphs, and list items.
        for tag in main_content.find_all(['h1', 'h2', 'h3', 'p', 'li']):
            text = ' '.join(tag.stripped_strings)
            if tag.name == 'li':
                content_lines.append(f"* {text}")
            else:
                content_lines.append(text)
        body_text = '\n'.join(content_lines)
    return {"body_text": body_text}

# Saves the given text content to a sequentially numbered file.
def save_content_to_file(body_text, file_heading, file_counter):
    file_content = f"{file_heading}\n\n{body_text}"
    filename = f"target{file_counter}.txt"
    filepath = os.path.join(OUTPUT_DIR, filename)
    try:
        with open(filepath, 'w', encoding='utf-8') as f:
            f.write(file_content)
        print(f"        -> Saved to {filepath}")
        return file_counter + 1
    except IOError as e:
        print(f"        -> ERROR: Could not write file {filepath}: {e}")
        return file_counter
    
# Main function to orchestrate the web scraping and file saving process.
def main():
    if not os.path.exists(OUTPUT_DIR):
        os.makedirs(OUTPUT_DIR)
        print(f"Created directory: {OUTPUT_DIR}")
    file_counter = 1
    with requests.Session() as session:
        session.headers.update({'User-Agent': 'MyCoolScraper/1.0'})
        category_links = get_main_category_links(session)
        print(f"Found {len(category_links)} categories.\n")
        for category_url in category_links:
            try:
                main_category_slug = category_url.strip('/').split('/')[-1]
                main_category_name = main_category_slug.replace('-', ' ').title()
            except IndexError:
                main_category_name = "Unknown Category"
            print(f"Processing Category: {main_category_name}")
            topic_links = get_topics_from_category(session, category_url)
            for topic_url, sub_topic_title in topic_links:
                print(f"  -> Processing Sub-Topic: {sub_topic_title}")
                content_links, found_selector = get_content_links_from_topic(session, topic_url)
                file_heading = f"{main_category_name}: {sub_topic_title}"
                if content_links:
                    # Case 1: The topic page is a landing page with more links.
                    print(f"    -> Found {len(content_links)} content pages (using selector: '{found_selector}')")
                    for content_url in content_links:
                        print(f"      -> Scraping: {content_url}")
                        data = scrape_page_content(session, content_url)
                        if data and data['body_text'].strip() and data['body_text'] != "No main content found":
                            file_counter = save_content_to_file(data['body_text'], file_heading, file_counter)
                        time.sleep(0.5)
                else:
                    # Case 2: The topic page is the final content page itself.
                    print(f"    -> No further links found. Scraping page directly.")
                    data = scrape_page_content(session, topic_url)
                    if data and data['body_text'].strip() and data['body_text'] != "No main content found":
                        file_counter = save_content_to_file(data['body_text'], file_heading, file_counter)
                    time.sleep(0.5)
            print("-" * 50)

    print(f"\nScraping complete. Total files saved: {file_counter - 1} in the '{OUTPUT_DIR}' directory.")

if __name__ == "__main__":
    main()
# Out:
# Created directory: scraped_content
# Fetching categories from: https://www.gov.uk/browse
# Found 16 categories.
#
# Processing Category: Abroad
#   -> Processing Sub-Topic: Living abroad
#     -> Found 21 content pages (using selector: 'main ul.govuk-list a[href]')
#       -> Scraping: https://www.gov.uk/world/all
#         -> Saved to scraped_content/target1.txt
#       -> Scraping: https://www.gov.uk/foreign-travel-advice
#         -> Saved to scraped_content/target2.txt
#       -> Scraping: https://www.gov.uk/get-document-legalised
#         -> Saved to scraped_content/target3.txt
#       -> Scraping: https://www.gov.uk/marriages-civil-partnerships-abroad
#         -> Saved to scraped_content/target4.txt
#       -> Scraping: https://www.gov.uk/register-a-death
#         -> Saved to scraped_content/target5.txt
#       -> Scraping: https://www.gov.uk/register-birth-abroad
#         -> Saved to scraped_content/target6.txt
#       -> Scraping: https://www.gov.uk/voting-when-abroad
#         -> Saved to scraped_content/target7.txt
#       -> Scraping: https://www.gov.uk/state-pension-if-you-retire-abroad
#         -> Saved to scraped_content/target8.txt
#       -> Scraping: https://www.gov.uk/moving-or-retiring-abroad
#         -> Saved to scraped_content/target9.txt
#       -> Scraping: https://www.gov.uk/national-insurance-if-you-go-abroad
#         -> Saved to scraped_content/target10.txt
#       -> Scraping: https://www.gov.uk/working-abroad
#         -> Saved to scraped_content/target11.txt
#       -> Scraping: https://www.gov.uk/tax-right-retire-abroad-return-to-uk
#         -> Saved to scraped_content/target12.txt
#       -> Scraping: https://www.gov.uk/tax-foreign-income
#         -> Saved to scraped_content/target13.txt
#       -> Scraping: https://www.gov.uk/tax-uk-income-live-abroad
#         -> Saved to scraped_content/target14.txt
#       -> Scraping: https://www.gov.uk/driving-abroad
#         -> Saved to scraped_content/target15.txt
#       -> Scraping: https://www.gov.uk/taking-vehicles-out-of-uk
#         -> Saved to scraped_content/target16.txt
#       -> Scraping: https://www.gov.uk/taking-your-pet-abroad
#         -> Saved to scraped_content/target17.txt
#       -> Scraping: https://www.gov.uk/claim-benefits-abroad
#         -> Saved to scraped_content/target18.txt
#       -> Scraping: https://www.gov.uk/victim-crime-abroad
#         -> Saved to scraped_content/target19.txt
#       -> Scraping: https://www.gov.uk/compensation-victim-crime-abroad
#         -> Saved to scraped_content/target20.txt
#       -> Scraping: https://www.gov.uk/compensation-victim-terrorist-attack
#         -> Saved to scraped_content/target21.txt
#   -> Processing Sub-Topic: Passports
#     -> Found 20 content pages (using selector: 'main ul.govuk-list a[href]')
#       -> Scraping: https://www.gov.uk/apply-renew-passport
#         -> Saved to scraped_content/target22.txt
#       -> Scraping: https://www.gov.uk/get-a-passport-urgently
#         -> Saved to scraped_content/target23.txt
#       -> Scraping: https://www.gov.uk/apply-first-adult-passport
#         -> Saved to scraped_content/target24.txt
#       -> Scraping: https://www.gov.uk/renew-adult-passport
#         -> Saved to scraped_content/target25.txt
#       -> Scraping: https://www.gov.uk/get-a-child-passport
#         -> Saved to scraped_content/target26.txt
#       -> Scraping: https://www.gov.uk/changing-passport-information
#         -> Saved to scraped_content/target27.txt
#       -> Scraping: https://www.gov.uk/collective-group-passports
#         -> Saved to scraped_content/target28.txt
#       -> Scraping: https://www.gov.uk/passport-application-while-visiting-uk
#         -> Saved to scraped_content/target29.txt
#       -> Scraping: https://www.gov.uk/travel-urgently-from-abroad-without-uk-passport
#         -> Saved to scraped_content/target30.txt
#       -> Scraping: https://www.gov.uk/photos-for-passports
#         -> Saved to scraped_content/target31.txt
#       -> Scraping: https://www.gov.uk/countersigning-passport-applications
#         -> Saved to scraped_content/target32.txt
#       -> Scraping: https://www.gov.uk/confirm-identity-online-for-passport-application
#         -> Saved to scraped_content/target33.txt
#       -> Scraping: https://www.gov.uk/british-passport-eligibility
#         -> Saved to scraped_content/target34.txt
#       -> Scraping: https://www.gov.uk/stop-child-passport
#         -> Saved to scraped_content/target35.txt
#       -> Scraping: https://www.gov.uk/passport-fees
#         -> Saved to scraped_content/target36.txt
#       -> Scraping: https://www.gov.uk/track-passport-application
#         -> Saved to scraped_content/target37.txt
#       -> Scraping: https://www.gov.uk/passport-advice-line
#         -> Saved to scraped_content/target38.txt
#       -> Scraping: https://www.gov.uk/passport-services-disabled
#         -> Saved to scraped_content/target39.txt
#       -> Scraping: https://www.gov.uk/how-the-post-office-check-and-send-service-works
#         -> Saved to scraped_content/target40.txt
#       -> Scraping: https://www.gov.uk/find-regional-passport-office
#         -> Saved to scraped_content/target41.txt
#   -> Processing Sub-Topic: Travel abroad
#     -> Found 30 content pages (using selector: 'main ul.govuk-list a[href]')
#       -> Scraping: https://www.gov.uk/foreign-travel-advice
#         -> Saved to scraped_content/target42.txt
#       -> Scraping: https://www.gov.uk/driving-abroad
#         -> Saved to scraped_content/target43.txt
#       -> Scraping: https://www.gov.uk/drive-abroad
#         -> Saved to scraped_content/target44.txt
#       -> Scraping: https://www.gov.uk/permission-take-child-abroad
#         -> Saved to scraped_content/target45.txt
#       -> Scraping: https://www.gov.uk/taking-vehicles-out-of-uk
#         -> Saved to scraped_content/target46.txt
#       -> Scraping: https://www.gov.uk/marriages-civil-partnerships-abroad
#         -> Saved to scraped_content/target47.txt
#       -> Scraping: https://www.gov.uk/taking-your-pet-abroad
#         -> Saved to scraped_content/target48.txt
#       -> Scraping: https://www.gov.uk/hand-luggage-restrictions
#         -> Saved to scraped_content/target49.txt
#       -> Scraping: https://www.gov.uk/airport-rights
#         -> Saved to scraped_content/target50.txt
#       -> Scraping: https://www.gov.uk/bringing-cash-into-uk
#         -> Saved to scraped_content/target51.txt
#       -> Scraping: https://www.gov.uk/global-entry-usa
#         -> Saved to scraped_content/target52.txt
#       -> Scraping: https://www.gov.uk/world/all
#         -> Saved to scraped_content/target53.txt
#       -> Scraping: https://www.gov.uk/claim-benefits-abroad
#         -> Saved to scraped_content/target54.txt
#       -> Scraping: https://www.gov.uk/get-document-legalised
#         -> Saved to scraped_content/target55.txt
#       -> Scraping: https://www.gov.uk/register-birth-abroad
#         -> Saved to scraped_content/target56.txt
#       -> Scraping: https://www.gov.uk/victim-crime-abroad
#         -> Saved to scraped_content/target57.txt
#       -> Scraping: https://www.gov.uk/register-a-death
#         -> Saved to scraped_content/target58.txt
#       -> Scraping: https://www.gov.uk/bringing-goods-into-uk-personal-use
#         -> Saved to scraped_content/target59.txt
#       -> Scraping: https://www.gov.uk/uk-border-control
#         -> Saved to scraped_content/target60.txt
#       -> Scraping: https://www.gov.uk/bringing-food-into-great-britain
#         -> Saved to scraped_content/target61.txt
#       -> Scraping: https://www.gov.uk/bringing-plants-and-wood-into-great-britain
#         -> Saved to scraped_content/target62.txt
#       -> Scraping: https://www.gov.uk/bring-pet-to-great-britain
#         -> Saved to scraped_content/target63.txt
#       -> Scraping: https://www.gov.uk/bring-your-pet-to-great-britain
#         -> Saved to scraped_content/target64.txt
#       -> Scraping: https://www.gov.uk/importing-vehicles-into-the-uk
#         -> Saved to scraped_content/target65.txt
#       -> Scraping: https://www.gov.uk/customs-seizures
#         -> Saved to scraped_content/target66.txt
#       -> Scraping: https://www.gov.uk/victim-crime-abroad
#         -> Saved to scraped_content/target67.txt
#       -> Scraping: https://www.gov.uk/compensation-victim-crime-abroad
#         -> Saved to scraped_content/target68.txt
#       -> Scraping: https://www.gov.uk/compensation-victim-terrorist-attack
#         -> Saved to scraped_content/target69.txt
#       -> Scraping: https://www.gov.uk/stop-forced-marriage
#         -> Saved to scraped_content/target70.txt
#       -> Scraping: https://www.gov.uk/female-genital-mutilation-help-advice
#         -> Saved to scraped_content/target71.txt
# --------------------------------------------------
# Processing Category: Benefits
#   -> Processing Sub-Topic: Manage an existing benefit, payment or claim
#     -> Found 37 content pages (using selector: 'main ul.govuk-list a[href]')
#       -> Scraping: https://www.gov.uk/sign-in-universal-credit
#         -> Saved to scraped_content/target72.txt
#       -> Scraping: https://www.gov.uk/sign-in-childcare-account
#         -> Saved to scraped_content/target73.txt
#       -> Scraping: https://www.gov.uk/sign-in-help-to-save
#         -> Saved to scraped_content/target74.txt
#       -> Scraping: https://www.gov.uk/send-fit-note
#         -> Saved to scraped_content/target75.txt
#       -> Scraping: https://www.gov.uk/how-to-have-your-benefits-paid
#         -> Saved to scraped_content/target76.txt
#       -> Scraping: https://www.gov.uk/short-term-benefit-advance
#         -> Saved to scraped_content/target77.txt
#       -> Scraping: https://www.gov.uk/child-benefit-payment-dates
#         -> Saved to scraped_content/target78.txt
#       -> Scraping: https://www.gov.uk/dwp-visit
#         -> Saved to scraped_content/target79.txt
#       -> Scraping: https://www.gov.uk/payment-exception-service
#         -> Saved to scraped_content/target80.txt
#       -> Scraping: https://www.gov.uk/bills-benefits
#         -> Saved to scraped_content/target81.txt
#       -> Scraping: https://www.gov.uk/repay-manage-benefit-owed
#         -> Saved to scraped_content/target82.txt
#       -> Scraping: https://www.gov.uk/disability-premiums
#         -> Saved to scraped_content/target83.txt
#       -> Scraping: https://www.gov.uk/cold-weather-payment
#         -> Saved to scraped_content/target84.txt
#       -> Scraping: https://www.gov.uk/winter-fuel-payment
#         -> Saved to scraped_content/target85.txt
#       -> Scraping: https://www.gov.uk/christmas-bonus
#         -> Saved to scraped_content/target86.txt
#       -> Scraping: https://www.gov.uk/report-benefits-change-circumstances
#         -> Saved to scraped_content/target87.txt
#       -> Scraping: https://www.gov.uk/claim-benefits-abroad
#         -> Saved to scraped_content/target88.txt
#       -> Scraping: https://www.gov.uk/going-to-hospital-benefits
#         -> Saved to scraped_content/target89.txt
#       -> Scraping: https://www.gov.uk/going-to-care-home-benefits
#         -> Saved to scraped_content/target90.txt
#       -> Scraping: https://www.gov.uk/benefits-and-prison
#         -> Saved to scraped_content/target91.txt
#       -> Scraping: https://www.gov.uk/benefits-end-of-life
#         -> Saved to scraped_content/target92.txt
#       -> Scraping: https://www.gov.uk/carers-allowance-report-change
#         -> Saved to scraped_content/target93.txt
#       -> Scraping: https://www.gov.uk/changes-affect-tax-credits
#         -> Saved to scraped_content/target94.txt
#       -> Scraping: https://www.gov.uk/report-changes-child-benefit
#         -> Saved to scraped_content/target95.txt
#       -> Scraping: https://www.gov.uk/become-appointee-for-someone-claiming-benefits
#         -> Saved to scraped_content/target96.txt
#       -> Scraping: https://www.gov.uk/benefit-cap
#         -> Saved to scraped_content/target97.txt
#       -> Scraping: https://www.gov.uk/mandatory-reconsideration
#         -> Saved to scraped_content/target98.txt
#       -> Scraping: https://www.gov.uk/appeal-benefit-decision
#         -> Saved to scraped_content/target99.txt
#       -> Scraping: https://www.gov.uk/appeal-housing-benefit-decision
#         -> Saved to scraped_content/target100.txt
#       -> Scraping: https://www.gov.uk/child-benefit-complaints
#         -> Saved to scraped_content/target101.txt
#       -> Scraping: https://www.gov.uk/tax-credits-appeals-complaints
#         -> Saved to scraped_content/target102.txt
#       -> Scraping: https://www.gov.uk/benefit-overpayments
#         -> Saved to scraped_content/target103.txt
#       -> Scraping: https://www.gov.uk/benefit-fraud
#         -> Saved to scraped_content/target104.txt
#       -> Scraping: https://www.gov.uk/report-benefit-fraud
#         -> Saved to scraped_content/target105.txt
#       -> Scraping: https://www.gov.uk/fraud-error-prevention-centres
#         -> Saved to scraped_content/target106.txt
#       -> Scraping: https://www.gov.uk/repay-child-benefit-overpayments
#         -> Saved to scraped_content/target107.txt
#       -> Scraping: https://www.gov.uk/tax-credits-overpayments
#         -> Saved to scraped_content/target108.txt
#   -> Processing Sub-Topic: Benefits and financial support if you're looking for work
#     -> Found 13 content pages (using selector: 'main ul.govuk-list a[href]')
#       -> Scraping: https://www.gov.uk/benefits-calculators
#         -> Saved to scraped_content/target109.txt
#       -> Scraping: https://www.gov.uk/check-benefits-financial-support
#         -> Saved to scraped_content/target110.txt
#       -> Scraping: https://www.gov.uk/jobseekers-allowance
#         -> Saved to scraped_content/target111.txt
#       -> Scraping: https://www.gov.uk/universal-credit
#         -> Saved to scraped_content/target112.txt
#       -> Scraping: https://www.gov.uk/pension-credit
#         -> Saved to scraped_content/target113.txt
#       -> Scraping: https://www.gov.uk/guidance/redundancy-help-finding-work-and-claiming-benefits
#         -> Saved to scraped_content/target114.txt
#       -> Scraping: https://www.gov.uk/find-a-job
#         -> Saved to scraped_content/target115.txt
#       -> Scraping: https://www.gov.uk/moving-from-benefits-to-work
#         -> Saved to scraped_content/target116.txt
#       -> Scraping: https://www.gov.uk/guidance/apply-for-communication-support-at-a-job-interview-if-you-have-a-disability-or-health-condition-access-to-work
#         -> Saved to scraped_content/target117.txt
#       -> Scraping: https://www.gov.uk/access-to-work
#         -> Saved to scraped_content/target118.txt
#       -> Scraping: https://www.gov.uk/get-help-savings-low-income
#         -> Saved to scraped_content/target119.txt
#       -> Scraping: https://www.gov.uk/budgeting-help-benefits
#         -> Saved to scraped_content/target120.txt
#       -> Scraping: https://www.gov.uk/support-visit-benefit-claim
#         -> Saved to scraped_content/target121.txt
#   -> Processing Sub-Topic: Benefits and financial support if you're temporarily unable to work
#     -> Found 5 content pages (using selector: 'main ul.govuk-list a[href]')
#       -> Scraping: https://www.gov.uk/benefits-calculators
#         -> Saved to scraped_content/target122.txt
#       -> Scraping: https://www.gov.uk/check-benefits-financial-support
#         -> Saved to scraped_content/target123.txt
#       -> Scraping: https://www.gov.uk/employment-support-allowance
#         -> Saved to scraped_content/target124.txt
#       -> Scraping: https://www.gov.uk/universal-credit
#         -> Saved to scraped_content/target125.txt
#       -> Scraping: https://www.gov.uk/statutory-sick-pay
#         -> Saved to scraped_content/target126.txt
#   -> Processing Sub-Topic: Benefits and financial support for families
#     -> Found 27 content pages (using selector: 'main ul.govuk-list a[href]')
#       -> Scraping: https://www.gov.uk/benefits-calculators
#         -> Saved to scraped_content/target127.txt
#       -> Scraping: https://www.gov.uk/check-benefits-financial-support
#         -> Saved to scraped_content/target128.txt
#       -> Scraping: https://www.gov.uk/maternity-pay-leave
#         -> Saved to scraped_content/target129.txt
#       -> Scraping: https://www.gov.uk/maternity-allowance
#         -> Saved to scraped_content/target130.txt
#       -> Scraping: https://www.gov.uk/sure-start-maternity-grant
#         -> Saved to scraped_content/target131.txt
#       -> Scraping: https://www.gov.uk/paternity-pay-leave
#         -> Saved to scraped_content/target132.txt
#       -> Scraping: https://www.gov.uk/shared-parental-leave-and-pay
#         -> Saved to scraped_content/target133.txt
#       -> Scraping: https://www.gov.uk/neonatal-care-pay-leave
#         -> Saved to scraped_content/target134.txt
#       -> Scraping: https://www.gov.uk/adoption-pay-leave
#         -> Saved to scraped_content/target135.txt
#       -> Scraping: https://www.gov.uk/parental-leave
#         -> Saved to scraped_content/target136.txt
#       -> Scraping: https://www.gov.uk/child-benefit
#         -> Saved to scraped_content/target137.txt
#       -> Scraping: https://www.gov.uk/child-benefit-16-19
#         -> Saved to scraped_content/target138.txt
#       -> Scraping: https://www.gov.uk/child-benefit-tax-calculator
#         -> Saved to scraped_content/target139.txt
#       -> Scraping: https://www.gov.uk/child-benefit-tax-charge
#         -> Saved to scraped_content/target140.txt
#       -> Scraping: https://www.gov.uk/child-maintenance-service
#         -> Saved to scraped_content/target141.txt
#       -> Scraping: https://www.gov.uk/disability-living-allowance-children
#         -> Saved to scraped_content/target142.txt
#       -> Scraping: https://www.gov.uk/help-for-disabled-child
#         -> Saved to scraped_content/target143.txt
#       -> Scraping: https://www.gov.uk/disabled-facilities-grants
#         -> Saved to scraped_content/target144.txt
#       -> Scraping: https://www.gov.uk/get-childcare
#         -> Saved to scraped_content/target145.txt
#       -> Scraping: https://www.gov.uk/help-with-childcare-costs
#         -> Saved to scraped_content/target146.txt
#       -> Scraping: https://www.gov.uk/childcare-grant
#         -> Saved to scraped_content/target147.txt
#       -> Scraping: https://www.gov.uk/care-to-learn
#         -> Saved to scraped_content/target148.txt
#       -> Scraping: https://www.gov.uk/apply-free-school-meals
#         -> Saved to scraped_content/target149.txt
#       -> Scraping: https://www.gov.uk/healthy-start
#         -> Saved to scraped_content/target150.txt
#       -> Scraping: https://www.gov.uk/guardians-allowance
#         -> Saved to scraped_content/target151.txt
#       -> Scraping: https://www.gov.uk/parents-learning-allowance
#         -> Saved to scraped_content/target152.txt
#       -> Scraping: https://www.gov.uk/support-visit-benefit-claim
#         -> Saved to scraped_content/target153.txt
#   -> Processing Sub-Topic: Benefits and financial support if you're disabled or have a health condition
#     -> Found 23 content pages (using selector: 'main ul.govuk-list a[href]')
#       -> Scraping: https://www.gov.uk/financial-help-disabled
#         -> Saved to scraped_content/target154.txt
#       -> Scraping: https://www.gov.uk/benefits-end-of-life
#         -> Saved to scraped_content/target155.txt
#       -> Scraping: https://www.gov.uk/benefits-calculators
#         -> Saved to scraped_content/target156.txt
#       -> Scraping: https://www.gov.uk/check-benefits-financial-support
#         -> Saved to scraped_content/target157.txt
#       -> Scraping: https://www.gov.uk/employment-support-allowance
#         -> Saved to scraped_content/target158.txt
#       -> Scraping: https://www.gov.uk/pip
#         -> Saved to scraped_content/target159.txt
#       -> Scraping: https://www.gov.uk/attendance-allowance
#         -> Saved to scraped_content/target160.txt
#       -> Scraping: https://www.gov.uk/disability-living-allowance-children
#         -> Saved to scraped_content/target161.txt
#       -> Scraping: https://www.gov.uk/health-conditions-disability-universal-credit
#         -> Saved to scraped_content/target162.txt
#       -> Scraping: https://www.gov.uk/industrial-injuries-disablement-benefit
#         -> Saved to scraped_content/target163.txt
#       -> Scraping: https://www.gov.uk/claim-for-injury-received-while-serving
#         -> Saved to scraped_content/target164.txt
#       -> Scraping: https://www.gov.uk/coal-health-compensation-claims
#         -> Saved to scraped_content/target165.txt
#       -> Scraping: https://www.gov.uk/diffuse-mesothelioma-payment
#         -> Saved to scraped_content/target166.txt
#       -> Scraping: https://www.gov.uk/reduced-earnings-allowance
#         -> Saved to scraped_content/target167.txt
#       -> Scraping: https://www.gov.uk/guidance/apply-for-communication-support-at-a-job-interview-if-you-have-a-disability-or-health-condition-access-to-work
#         -> Saved to scraped_content/target168.txt
#       -> Scraping: https://www.gov.uk/access-to-work
#         -> Saved to scraped_content/target169.txt
#       -> Scraping: https://www.gov.uk/blind-persons-allowance
#         -> Saved to scraped_content/target170.txt
#       -> Scraping: https://www.gov.uk/disabled-facilities-grants
#         -> Saved to scraped_content/target171.txt
#       -> Scraping: https://www.gov.uk/vaccine-damage-payment
#         -> Saved to scraped_content/target172.txt
#       -> Scraping: https://www.gov.uk/disabled-students-allowance-dsa
#         -> Saved to scraped_content/target173.txt
#       -> Scraping: https://www.gov.uk/help-for-disabled-child
#         -> Saved to scraped_content/target174.txt
#       -> Scraping: https://www.gov.uk/if-you-become-disabled
#         -> Saved to scraped_content/target175.txt
#       -> Scraping: https://www.gov.uk/support-visit-benefit-claim
#         -> Saved to scraped_content/target176.txt
#   -> Processing Sub-Topic: Benefits and financial support if you're caring for someone
#     -> Found 10 content pages (using selector: 'main ul.govuk-list a[href]')
#       -> Scraping: https://www.gov.uk/benefits-calculators
#         -> Saved to scraped_content/target177.txt
#       -> Scraping: https://www.gov.uk/check-benefits-financial-support
#         -> Saved to scraped_content/target178.txt
#       -> Scraping: https://www.gov.uk/carers-allowance
#         -> Saved to scraped_content/target179.txt
#       -> Scraping: https://www.gov.uk/carers-credit
#         -> Saved to scraped_content/target180.txt
#       -> Scraping: https://www.gov.uk/universal-credit
#         -> Saved to scraped_content/target181.txt
#       -> Scraping: https://www.gov.uk/pension-credit
#         -> Saved to scraped_content/target182.txt
#       -> Scraping: https://www.gov.uk/become-appointee-for-someone-claiming-benefits
#         -> Saved to scraped_content/target183.txt
#       -> Scraping: https://www.gov.uk/support-visit-benefit-claim
#         -> Saved to scraped_content/target184.txt
#       -> Scraping: https://www.gov.uk/carers-allowance-unit
#         -> Saved to scraped_content/target185.txt
#       -> Scraping: https://www.gov.uk/attendance-allowance
#         -> Saved to scraped_content/target186.txt
#   -> Processing Sub-Topic: Benefits and financial support if you're on a low income
#     -> Found 20 content pages (using selector: 'main ul.govuk-list a[href]')
#       -> Scraping: https://www.gov.uk/benefits-calculators
#         -> Saved to scraped_content/target187.txt
#       -> Scraping: https://www.gov.uk/check-benefits-financial-support
#         -> Saved to scraped_content/target188.txt
#       -> Scraping: https://www.gov.uk/universal-credit
#         -> Saved to scraped_content/target189.txt
#       -> Scraping: https://www.gov.uk/housing-benefit
#         -> Saved to scraped_content/target190.txt
#       -> Scraping: https://www.gov.uk/support-for-mortgage-interest
#         -> Saved to scraped_content/target191.txt
#       -> Scraping: https://www.gov.uk/mortgage-interest-run-on
#         -> Saved to scraped_content/target192.txt
#       -> Scraping: https://www.gov.uk/apply-council-tax-reduction
#         -> Saved to scraped_content/target193.txt
#       -> Scraping: https://www.gov.uk/apply-housing-benefit-from-council
#         -> Saved to scraped_content/target194.txt
#       -> Scraping: https://www.gov.uk/the-warm-home-discount-scheme
#         -> Saved to scraped_content/target195.txt
#       -> Scraping: https://www.gov.uk/national-concessionary-fuel-scheme
#         -> Saved to scraped_content/target196.txt
#       -> Scraping: https://www.gov.uk/winter-fuel-payment
#         -> Saved to scraped_content/target197.txt
#       -> Scraping: https://www.gov.uk/free-discount-tv-licence
#         -> Saved to scraped_content/target198.txt
#       -> Scraping: https://www.gov.uk/pension-credit
#         -> Saved to scraped_content/target199.txt
#       -> Scraping: https://www.gov.uk/self-employment-and-universal-credit
#         -> Saved to scraped_content/target200.txt
#       -> Scraping: https://www.gov.uk/cost-living-help-local-council
#         -> Saved to scraped_content/target201.txt
#       -> Scraping: https://www.gov.uk/disabled-facilities-grants
#         -> Saved to scraped_content/target202.txt
#       -> Scraping: https://www.gov.uk/bills-benefits
#         -> Saved to scraped_content/target203.txt
#       -> Scraping: https://www.gov.uk/help-nhs-costs
#         -> Saved to scraped_content/target204.txt
#       -> Scraping: https://www.gov.uk/get-a-ppc
#         -> Saved to scraped_content/target205.txt
#       -> Scraping: https://www.gov.uk/support-visit-benefit-claim
#         -> Saved to scraped_content/target206.txt
#   -> Processing Sub-Topic: Benefits and financial support when someone dies
#     -> Found 13 content pages (using selector: 'main ul.govuk-list a[href]')
#       -> Scraping: https://www.gov.uk/benefits-calculators
#         -> Saved to scraped_content/target207.txt
#       -> Scraping: https://www.gov.uk/bereavement-support-payment
#         -> Saved to scraped_content/target208.txt
#       -> Scraping: https://www.gov.uk/child-benefit-child-parent-dies
#         -> Saved to scraped_content/target209.txt
#       -> Scraping: https://www.gov.uk/funeral-payments
#         -> Saved to scraped_content/target210.txt
#       -> Scraping: https://www.gov.uk/guardians-allowance
#         -> Saved to scraped_content/target211.txt
#       -> Scraping: https://www.gov.uk/child-funeral-costs
#         -> Saved to scraped_content/target212.txt
#       -> Scraping: https://www.gov.uk/parental-bereavement-pay-leave
#         -> Saved to scraped_content/target213.txt
#       -> Scraping: https://www.gov.uk/universal-credit
#         -> Saved to scraped_content/target214.txt
#       -> Scraping: https://www.gov.uk/widowed-parents-allowance
#         -> Saved to scraped_content/target215.txt
#       -> Scraping: https://www.gov.uk/war-widow-pension
#         -> Saved to scraped_content/target216.txt
#       -> Scraping: https://www.gov.uk/when-someone-dies
#         -> Saved to scraped_content/target217.txt
#       -> Scraping: https://www.gov.uk/death-spouse-benefits-tax-pension
#         -> Saved to scraped_content/target218.txt
#       -> Scraping: https://www.gov.uk/support-visit-benefit-claim
#         -> Saved to scraped_content/target219.txt
# --------------------------------------------------
# Processing Category: Births Deaths Marriages
#   -> Processing Sub-Topic: Certificates, register offices, changes of name or gender
#     -> Found 25 content pages (using selector: 'main ul.govuk-list a[href]')
#       -> Scraping: https://www.gov.uk/adding-fathers-name-birth-certificate
#         -> Saved to scraped_content/target220.txt
#       -> Scraping: https://www.gov.uk/adoption-records
#         -> Saved to scraped_content/target221.txt
#       -> Scraping: https://www.gov.uk/apply-gender-recognition-certificate
#         -> Saved to scraped_content/target222.txt
#       -> Scraping: https://www.gov.uk/certifying-a-document
#         -> Saved to scraped_content/target223.txt
#       -> Scraping: https://www.gov.uk/change-name-deed-poll
#         -> Saved to scraped_content/target224.txt
#       -> Scraping: https://www.gov.uk/correct-birth-registration
#         -> Saved to scraped_content/target225.txt
#       -> Scraping: https://www.gov.uk/correcting-a-death-registration
#         -> Saved to scraped_content/target226.txt
#       -> Scraping: https://www.gov.uk/correct-marriage-registration
#         -> Saved to scraped_content/target227.txt
#       -> Scraping: https://www.gov.uk/register-offices
#         -> Saved to scraped_content/target228.txt
#       -> Scraping: https://www.gov.uk/general-register-office
#         -> Saved to scraped_content/target229.txt
#       -> Scraping: https://www.gov.uk/general-register-office-for-northern-ireland
#         -> Saved to scraped_content/target230.txt
#       -> Scraping: https://www.gov.uk/get-copy-military-records-of-service
#         -> Saved to scraped_content/target231.txt
#       -> Scraping: https://www.gov.uk/get-document-legalised
#         -> Saved to scraped_content/target232.txt
#       -> Scraping: https://www.gov.uk/marriages-civil-partnerships
#         -> Saved to scraped_content/target233.txt
#       -> Scraping: https://www.gov.uk/national-records-of-scotland
#         -> Saved to scraped_content/target234.txt
#       -> Scraping: https://www.gov.uk/order-copy-birth-death-marriage-certificate
#         -> Saved to scraped_content/target235.txt
#       -> Scraping: https://www.gov.uk/commemorative-marriage-certificate
#         -> Saved to scraped_content/target236.txt
#       -> Scraping: https://www.gov.uk/register-birth
#         -> Saved to scraped_content/target237.txt
#       -> Scraping: https://www.gov.uk/register-birth-abroad
#         -> Saved to scraped_content/target238.txt
#       -> Scraping: https://www.gov.uk/register-a-death
#         -> Saved to scraped_content/target239.txt
#       -> Scraping: https://www.gov.uk/register-stillbirth
#         -> Saved to scraped_content/target240.txt
#       -> Scraping: https://www.gov.uk/research-family-history
#         -> Saved to scraped_content/target241.txt
#       -> Scraping: https://www.gov.uk/verify-apostille
#         -> Saved to scraped_content/target242.txt
#       -> Scraping: https://www.gov.uk/after-a-death
#         -> Saved to scraped_content/target243.txt
#       -> Scraping: https://www.gov.uk/when-someone-dies
#         -> Saved to scraped_content/target244.txt
#   -> Processing Sub-Topic: Child Benefit
#     -> Found 15 content pages (using selector: 'main ul.govuk-list a[href]')
#       -> Scraping: https://www.gov.uk/child-benefit
#         -> Saved to scraped_content/target245.txt
#       -> Scraping: https://www.gov.uk/child-benefit-complaints
#         -> Saved to scraped_content/target246.txt
#       -> Scraping: https://www.gov.uk/child-benefit-for-children-in-hospital-or-care
#         -> Saved to scraped_content/target247.txt
#       -> Scraping: https://www.gov.uk/child-benefit-child-parent-dies
#         -> Saved to scraped_content/target248.txt
#       -> Scraping: https://www.gov.uk/child-benefit-abroad
#         -> Saved to scraped_content/target249.txt
#       -> Scraping: https://www.gov.uk/child-benefit-move-to-uk
#         -> Saved to scraped_content/target250.txt
#       -> Scraping: https://www.gov.uk/child-benefit-child-lives-with-someone-else
#         -> Saved to scraped_content/target251.txt
#       -> Scraping: https://www.gov.uk/child-benefit-payment-dates
#         -> Saved to scraped_content/target252.txt
#       -> Scraping: https://www.gov.uk/child-benefit-tax-calculator
#         -> Saved to scraped_content/target253.txt
#       -> Scraping: https://www.gov.uk/child-benefit-16-19
#         -> Saved to scraped_content/target254.txt
#       -> Scraping: https://www.gov.uk/claim-child-benefit-behalf-someone-else
#         -> Saved to scraped_content/target255.txt
#       -> Scraping: https://www.gov.uk/guardians-allowance
#         -> Saved to scraped_content/target256.txt
#       -> Scraping: https://www.gov.uk/child-benefit-tax-charge
#         -> Saved to scraped_content/target257.txt
#       -> Scraping: https://www.gov.uk/child-benefit-proof
#         -> Saved to scraped_content/target258.txt
#       -> Scraping: https://www.gov.uk/report-changes-child-benefit
#         -> Saved to scraped_content/target259.txt
#   -> Processing Sub-Topic: Death and bereavement
#     -> Found 34 content pages (using selector: 'main ul.govuk-list a[href]')
#       -> Scraping: https://www.gov.uk/when-someone-dies
#         -> Saved to scraped_content/target260.txt
#       -> Scraping: https://www.gov.uk/register-a-death
#         -> Saved to scraped_content/target261.txt
#       -> Scraping: https://www.gov.uk/register-stillbirth
#         -> Saved to scraped_content/target262.txt
#       -> Scraping: https://www.gov.uk/applying-for-probate
#         -> Saved to scraped_content/target263.txt
#       -> Scraping: https://www.gov.uk/stop-probate-application
#         -> Saved to scraped_content/target264.txt
#       -> Scraping: https://www.gov.uk/update-property-records-someone-dies
#         -> Saved to scraped_content/target265.txt
#       -> Scraping: https://www.gov.uk/get-declaration-presumed-death
#         -> Saved to scraped_content/target266.txt
#       -> Scraping: https://www.gov.uk/change-cancel-presumption-death-certificate
#         -> Saved to scraped_content/target267.txt
#       -> Scraping: https://www.gov.uk/challenge-presumption-death-claim
#         -> Saved to scraped_content/target268.txt
#       -> Scraping: https://www.gov.uk/after-a-death
#         -> Saved to scraped_content/target269.txt
#       -> Scraping: https://www.gov.uk/tell-dvla-about-bereavement
#         -> Saved to scraped_content/target270.txt
#       -> Scraping: https://www.gov.uk/probate-estate
#         -> Saved to scraped_content/target271.txt
#       -> Scraping: https://www.gov.uk/valuing-estate-of-someone-who-died
#         -> Saved to scraped_content/target272.txt
#       -> Scraping: https://www.gov.uk/unclaimed-estates-bona-vacantia
#         -> Saved to scraped_content/target273.txt
#       -> Scraping: https://www.gov.uk/find-unclaimed-court-money
#         -> Saved to scraped_content/target274.txt
#       -> Scraping: https://www.gov.uk/make-will
#         -> Saved to scraped_content/target275.txt
#       -> Scraping: https://www.gov.uk/search-will-probate
#         -> Saved to scraped_content/target276.txt
#       -> Scraping: https://www.gov.uk/inherits-someone-dies-without-will
#         -> Saved to scraped_content/target277.txt
#       -> Scraping: https://www.gov.uk/apply-statutory-will
#         -> Saved to scraped_content/target278.txt
#       -> Scraping: https://www.gov.uk/alter-a-will-after-a-death
#         -> Saved to scraped_content/target279.txt
#       -> Scraping: https://www.gov.uk/probate-search
#         -> Saved to scraped_content/target280.txt
#       -> Scraping: https://www.gov.uk/inheritance-tax
#         -> Saved to scraped_content/target281.txt
#       -> Scraping: https://www.gov.uk/paying-inheritance-tax
#         -> Saved to scraped_content/target282.txt
#       -> Scraping: https://www.gov.uk/business-relief-inheritance-tax
#         -> Saved to scraped_content/target283.txt
#       -> Scraping: https://www.gov.uk/tax-property-money-shares-you-inherit
#         -> Saved to scraped_content/target284.txt
#       -> Scraping: https://www.gov.uk/public-trustee-executor-will
#         -> Saved to scraped_content/target285.txt
#       -> Scraping: https://www.gov.uk/find-bereavement-services-from-council
#         -> Saved to scraped_content/target286.txt
#       -> Scraping: https://www.gov.uk/parental-bereavement-pay-leave
#         -> Saved to scraped_content/target287.txt
#       -> Scraping: https://www.gov.uk/funeral-payments
#         -> Saved to scraped_content/target288.txt
#       -> Scraping: https://www.gov.uk/child-funeral-costs
#         -> Saved to scraped_content/target289.txt
#       -> Scraping: https://www.gov.uk/bereavement-support-payment
#         -> Saved to scraped_content/target290.txt
#       -> Scraping: https://www.gov.uk/guardians-allowance
#         -> Saved to scraped_content/target291.txt
#       -> Scraping: https://www.gov.uk/widowed-parents-allowance
#         -> Saved to scraped_content/target292.txt
#       -> Scraping: https://www.gov.uk/death-spouse-benefits-tax-pension
#         -> Saved to scraped_content/target293.txt
#   -> Processing Sub-Topic: Having a child, parenting and adoption
#     -> Found 49 content pages (using selector: 'main ul.govuk-list a[href]')
#       -> Scraping: https://www.gov.uk/adding-fathers-name-birth-certificate
#         -> Saved to scraped_content/target294.txt
#       -> Scraping: https://www.gov.uk/adoption-records
#         -> Saved to scraped_content/target295.txt
#       -> Scraping: https://www.gov.uk/alcohol-young-people-law
#         -> Saved to scraped_content/target296.txt
#       -> Scraping: https://www.gov.uk/apply-for-tax-free-childcare
#         -> Saved to scraped_content/target297.txt
#       -> Scraping: https://www.gov.uk/apply-short-term-care-for-child
#         -> Saved to scraped_content/target298.txt
#       -> Scraping: https://www.gov.uk/apply-to-adopt-child-through-council
#         -> Saved to scraped_content/target299.txt
#       -> Scraping: https://www.gov.uk/apply-foster-child-council
#         -> Saved to scraped_content/target300.txt
#       -> Scraping: https://www.gov.uk/apply-special-guardian
#         -> Saved to scraped_content/target301.txt
#       -> Scraping: https://www.gov.uk/becoming-foster-parent
#         -> Saved to scraped_content/target302.txt
#       -> Scraping: https://www.gov.uk/calculate-child-maintenance
#         -> Saved to scraped_content/target303.txt
#       -> Scraping: https://www.gov.uk/child-maintenance-service
#         -> Saved to scraped_content/target304.txt
#       -> Scraping: https://www.gov.uk/child-trust-funds
#         -> Saved to scraped_content/target305.txt
#       -> Scraping: https://www.gov.uk/child-adoption
#         -> Saved to scraped_content/target306.txt
#       -> Scraping: https://www.gov.uk/child-employment
#         -> Saved to scraped_content/target307.txt
#       -> Scraping: https://www.gov.uk/child-maintenance-if-one-parent-lives-abroad
#         -> Saved to scraped_content/target308.txt
#       -> Scraping: https://www.gov.uk/childcare-grant
#         -> Saved to scraped_content/target309.txt
#       -> Scraping: https://www.gov.uk/childcare-out-of-school-hours
#         -> Saved to scraped_content/target310.txt
#       -> Scraping: https://www.gov.uk/early-years-foundation-stage
#         -> Saved to scraped_content/target311.txt
#       -> Scraping: https://www.gov.uk/find-sure-start-childrens-centre
#         -> Saved to scraped_content/target312.txt
#       -> Scraping: https://www.gov.uk/find-registered-childminder
#         -> Saved to scraped_content/target313.txt
#       -> Scraping: https://www.gov.uk/find-ofsted-inspection-report
#         -> Saved to scraped_content/target314.txt
#       -> Scraping: https://www.gov.uk/find-free-early-education
#         -> Saved to scraped_content/target315.txt
#       -> Scraping: https://www.gov.uk/return-or-contact-abducted-child
#         -> Saved to scraped_content/target316.txt
#       -> Scraping: https://www.gov.uk/get-tax-free-childcare
#         -> Saved to scraped_content/target317.txt
#       -> Scraping: https://www.gov.uk/police-check-someone-involved-with-child
#         -> Saved to scraped_content/target318.txt
#       -> Scraping: https://www.gov.uk/get-childcare
#         -> Saved to scraped_content/target319.txt
#       -> Scraping: https://www.gov.uk/support-for-foster-parents
#         -> Saved to scraped_content/target320.txt
#       -> Scraping: https://www.gov.uk/help-for-disabled-child
#         -> Saved to scraped_content/target321.txt
#       -> Scraping: https://www.gov.uk/help-with-childcare-costs
#         -> Saved to scraped_content/target322.txt
#       -> Scraping: https://www.gov.uk/how-child-maintenance-is-worked-out
#         -> Saved to scraped_content/target323.txt
#       -> Scraping: https://www.gov.uk/if-your-child-is-taken-into-care
#         -> Saved to scraped_content/target324.txt
#       -> Scraping: https://www.gov.uk/savings-for-children
#         -> Saved to scraped_content/target325.txt
#       -> Scraping: https://www.gov.uk/junior-individual-savings-accounts
#         -> Saved to scraped_content/target326.txt
#       -> Scraping: https://www.gov.uk/legal-rights-for-egg-and-sperm-donors
#         -> Saved to scraped_content/target327.txt
#       -> Scraping: https://www.gov.uk/looking-after-someone-elses-child
#         -> Saved to scraped_content/target328.txt
#       -> Scraping: https://www.gov.uk/parental-rights-responsibilities
#         -> Saved to scraped_content/target329.txt
#       -> Scraping: https://www.gov.uk/parents-learning-allowance
#         -> Saved to scraped_content/target330.txt
#       -> Scraping: https://www.gov.uk/plan-shared-parental-leave-pay
#         -> Saved to scraped_content/target331.txt
#       -> Scraping: https://www.gov.uk/working-when-pregnant-your-rights
#         -> Saved to scraped_content/target332.txt
#       -> Scraping: https://www.gov.uk/register-birth
#         -> Saved to scraped_content/target333.txt
#       -> Scraping: https://www.gov.uk/register-birth-abroad
#         -> Saved to scraped_content/target334.txt
#       -> Scraping: https://www.gov.uk/register-stillbirth
#         -> Saved to scraped_content/target335.txt
#       -> Scraping: https://www.gov.uk/request-baby-loss-certificate
#         -> Saved to scraped_content/target336.txt
#       -> Scraping: https://www.gov.uk/sure-start-maternity-grant
#         -> Saved to scraped_content/target337.txt
#       -> Scraping: https://www.gov.uk/legal-rights-when-using-surrogates-and-donors
#         -> Saved to scraped_content/target338.txt
#       -> Scraping: https://www.gov.uk/tax-free-childcare
#         -> Saved to scraped_content/target339.txt
#       -> Scraping: https://www.gov.uk/law-on-leaving-your-child-home-alone
#         -> Saved to scraped_content/target340.txt
#       -> Scraping: https://www.gov.uk/unpaid-child-maintenance
#         -> Saved to scraped_content/target341.txt
#       -> Scraping: https://www.gov.uk/parental-leave
#         -> Saved to scraped_content/target342.txt
#   -> Processing Sub-Topic: Lasting power of attorney, being in care and managing finances
#     -> Found 25 content pages (using selector: 'main ul.govuk-list a[href]')
#       -> Scraping: https://www.gov.uk/oneoff-decision-personal-welfare
#         -> Saved to scraped_content/target343.txt
#       -> Scraping: https://www.gov.uk/mental-health-tribunal
#         -> Saved to scraped_content/target344.txt
#       -> Scraping: https://www.gov.uk/become-appointee-for-someone-claiming-benefits
#         -> Saved to scraped_content/target345.txt
#       -> Scraping: https://www.gov.uk/carers-allowance
#         -> Saved to scraped_content/target346.txt
#       -> Scraping: https://www.gov.uk/deputyship-refund
#         -> Saved to scraped_content/target347.txt
#       -> Scraping: https://www.gov.uk/power-of-attorney-refund
#         -> Saved to scraped_content/target348.txt
#       -> Scraping: https://www.gov.uk/claim-child-benefit-behalf-someone-else
#         -> Saved to scraped_content/target349.txt
#       -> Scraping: https://www.gov.uk/contact-court-funds-office
#         -> Saved to scraped_content/target350.txt
#       -> Scraping: https://www.gov.uk/dealing-tax-credits-someone-else
#         -> Saved to scraped_content/target351.txt
#       -> Scraping: https://www.gov.uk/become-deputy
#         -> Saved to scraped_content/target352.txt
#       -> Scraping: https://www.gov.uk/court-funds-office-processes
#         -> Saved to scraped_content/target353.txt
#       -> Scraping: https://www.gov.uk/enduring-power-attorney-duties
#         -> Saved to scraped_content/target354.txt
#       -> Scraping: https://www.gov.uk/find-someones-attorney-deputy-or-guardian
#         -> Saved to scraped_content/target355.txt
#       -> Scraping: https://www.gov.uk/get-court-funds-money-when-you-recover
#         -> Saved to scraped_content/target356.txt
#       -> Scraping: https://www.gov.uk/get-court-funds-money-when-you-turn-18
#         -> Saved to scraped_content/target357.txt
#       -> Scraping: https://www.gov.uk/leaving-foster-or-local-authority-care
#         -> Saved to scraped_content/target358.txt
#       -> Scraping: https://www.gov.uk/emergency-court-of-protection
#         -> Saved to scraped_content/target359.txt
#       -> Scraping: https://www.gov.uk/make-decisions-for-someone
#         -> Saved to scraped_content/target360.txt
#       -> Scraping: https://www.gov.uk/power-of-attorney
#         -> Saved to scraped_content/target361.txt
#       -> Scraping: https://www.gov.uk/manage-missing-persons-finances
#         -> Saved to scraped_content/target362.txt
#       -> Scraping: https://www.gov.uk/object-registration-power-attorney
#         -> Saved to scraped_content/target363.txt
#       -> Scraping: https://www.gov.uk/report-concern-about-attorney-deputy-guardian
#         -> Saved to scraped_content/target364.txt
#       -> Scraping: https://www.gov.uk/use-lasting-power-attorney
#         -> Saved to scraped_content/target365.txt
#       -> Scraping: https://www.gov.uk/use-or-cancel-an-enduring-power-of-attorney
#         -> Saved to scraped_content/target366.txt
#       -> Scraping: https://www.gov.uk/view-lasting-power-of-attorney
#         -> Saved to scraped_content/target367.txt
#   -> Processing Sub-Topic: Marriage, civil partnership and divorce
#     -> Found 26 content pages (using selector: 'main ul.govuk-list a[href]')
#       -> Scraping: https://www.gov.uk/marriages-civil-partnerships
#         -> Saved to scraped_content/target368.txt
#       -> Scraping: https://www.gov.uk/marriages-civil-partnerships-abroad
#         -> Saved to scraped_content/target369.txt
#       -> Scraping: https://www.gov.uk/come-uk-married
#         -> Saved to scraped_content/target370.txt
#       -> Scraping: https://www.gov.uk/commemorative-marriage-certificate
#         -> Saved to scraped_content/target371.txt
#       -> Scraping: https://www.gov.uk/change-name-deed-poll
#         -> Saved to scraped_content/target372.txt
#       -> Scraping: https://www.gov.uk/convert-civil-partnership
#         -> Saved to scraped_content/target373.txt
#       -> Scraping: https://www.gov.uk/stop-forced-marriage
#         -> Saved to scraped_content/target374.txt
#       -> Scraping: https://www.gov.uk/order-copy-birth-death-marriage-certificate
#         -> Saved to scraped_content/target375.txt
#       -> Scraping: https://www.gov.uk/separation-divorce
#         -> Saved to scraped_content/target376.txt
#       -> Scraping: https://www.gov.uk/legal-separation
#         -> Saved to scraped_content/target377.txt
#       -> Scraping: https://www.gov.uk/how-to-annul-marriage
#         -> Saved to scraped_content/target378.txt
#       -> Scraping: https://www.gov.uk/divorce-missing-husband-wife
#         -> Saved to scraped_content/target379.txt
#       -> Scraping: https://www.gov.uk/copy-decree-absolute-final-order
#         -> Saved to scraped_content/target380.txt
#       -> Scraping: https://www.gov.uk/money-property-when-relationship-ends
#         -> Saved to scraped_content/target381.txt
#       -> Scraping: https://www.gov.uk/divorce
#         -> Saved to scraped_content/target382.txt
#       -> Scraping: https://www.gov.uk/end-civil-partnership
#         -> Saved to scraped_content/target383.txt
#       -> Scraping: https://www.gov.uk/visas-when-you-separate-or-divorce
#         -> Saved to scraped_content/target384.txt
#       -> Scraping: https://www.gov.uk/contact-grandchild-parents-divorce-separate
#         -> Saved to scraped_content/target385.txt
#       -> Scraping: https://www.gov.uk/looking-after-children-divorce
#         -> Saved to scraped_content/target386.txt
#       -> Scraping: https://www.gov.uk/child-maintenance-service
#         -> Saved to scraped_content/target387.txt
#       -> Scraping: https://www.gov.uk/stay-in-home-during-separation-or-divorce
#         -> Saved to scraped_content/target388.txt
#       -> Scraping: https://www.gov.uk/childcare-grant
#         -> Saved to scraped_content/target389.txt
#       -> Scraping: https://www.gov.uk/sure-start-maternity-grant
#         -> Saved to scraped_content/target390.txt
#       -> Scraping: https://www.gov.uk/childcare-out-of-school-hours
#         -> Saved to scraped_content/target391.txt
#       -> Scraping: https://www.gov.uk/find-sure-start-childrens-centre
#         -> Saved to scraped_content/target392.txt
#       -> Scraping: https://www.gov.uk/law-on-leaving-your-child-home-alone
#         -> Saved to scraped_content/target393.txt
# --------------------------------------------------
# Processing Category: Business
#   -> Processing Sub-Topic: Setting up
#     -> Found 13 content pages (using selector: 'main ul.govuk-list a[href]')
# ...
#       -> Scraping: https://www.gov.uk/universal-credit
#         -> Saved to scraped_content/target2654.txt
#       -> Scraping: https://www.gov.uk/volunteering
#         -> Saved to scraped_content/target2655.txt
#       -> Scraping: https://www.gov.uk/jobsearch-rights
#         -> Saved to scraped_content/target2656.txt
#   -> Processing Sub-Topic: Holidays, time off, sick leave, maternity and paternity leave
#     -> Found 26 content pages (using selector: 'main ul.govuk-list a[href]')
#       -> Scraping: https://www.gov.uk/adoption-pay-leave
#         -> Saved to scraped_content/target2657.txt
#       -> Scraping: https://www.gov.uk/agricultural-sick-pay
#         -> Saved to scraped_content/target2658.txt
#       -> Scraping: https://www.gov.uk/appeal-call-up-reserve-forces
#         -> Saved to scraped_content/target2659.txt
#       -> Scraping: https://www.gov.uk/calculate-your-holiday-entitlement
#         -> Saved to scraped_content/target2660.txt
#       -> Scraping: https://www.gov.uk/calculate-agricultural-holiday-entitlement
#         -> Saved to scraped_content/target2661.txt
#       -> Scraping: https://www.gov.uk/career-breaks
#         -> Saved to scraped_content/target2662.txt
#       -> Scraping: https://www.gov.uk/maternity-paternity-pay-leave
#         -> Saved to scraped_content/target2663.txt
#       -> Scraping: https://www.gov.uk/employee-rights-when-on-leave
#         -> Saved to scraped_content/target2664.txt
#       -> Scraping: https://www.gov.uk/holiday-entitlement-rights
#         -> Saved to scraped_content/target2665.txt
#       -> Scraping: https://www.gov.uk/maternity-allowance
#         -> Saved to scraped_content/target2666.txt
#       -> Scraping: https://www.gov.uk/maternity-pay-leave
#         -> Saved to scraped_content/target2667.txt
#       -> Scraping: https://www.gov.uk/neonatal-care-pay-leave
#         -> Saved to scraped_content/target2668.txt
#       -> Scraping: https://www.gov.uk/paternity-pay-leave
#         -> Saved to scraped_content/target2669.txt
#       -> Scraping: https://www.gov.uk/plan-shared-parental-leave-pay
#         -> Saved to scraped_content/target2670.txt
#       -> Scraping: https://www.gov.uk/shared-parental-leave-and-pay
#         -> Saved to scraped_content/target2671.txt
#       -> Scraping: https://www.gov.uk/parental-bereavement-pay-leave
#         -> Saved to scraped_content/target2672.txt
#       -> Scraping: https://www.gov.uk/statutory-sick-pay
#         -> Saved to scraped_content/target2673.txt
#       -> Scraping: https://www.gov.uk/medical-suspensions-from-work
#         -> Saved to scraped_content/target2674.txt
#       -> Scraping: https://www.gov.uk/taking-sick-leave
#         -> Saved to scraped_content/target2675.txt
#       -> Scraping: https://www.gov.uk/time-off-for-dependants
#         -> Saved to scraped_content/target2676.txt
#       -> Scraping: https://www.gov.uk/time-off-work-public-duties
#         -> Saved to scraped_content/target2677.txt
#       -> Scraping: https://www.gov.uk/training-study-work-your-rights
#         -> Saved to scraped_content/target2678.txt
#       -> Scraping: https://www.gov.uk/travel-disruption-your-rights-at-work
#         -> Saved to scraped_content/target2679.txt
#       -> Scraping: https://www.gov.uk/bank-holidays
#         -> Saved to scraped_content/target2680.txt
#       -> Scraping: https://www.gov.uk/carers-leave
#         -> Saved to scraped_content/target2681.txt
#       -> Scraping: https://www.gov.uk/parental-leave
#         -> Saved to scraped_content/target2682.txt
#   -> Processing Sub-Topic: Redundancies, dismissals and disciplinaries
#     -> Found 16 content pages (using selector: 'main ul.govuk-list a[href]')
#       -> Scraping: https://www.gov.uk/guidance/redundancy-help-finding-work-and-claiming-benefits
#         -> Saved to scraped_content/target2683.txt
#       -> Scraping: https://www.gov.uk/armed-forces-redundancy-calculator
#         -> Saved to scraped_content/target2684.txt
#       -> Scraping: https://www.gov.uk/calculate-your-redundancy-pay
#         -> Saved to scraped_content/target2685.txt
#       -> Scraping: https://www.gov.uk/claim-loss-notice
#         -> Saved to scraped_content/target2686.txt
#       -> Scraping: https://www.gov.uk/claim-redundancy
#         -> Saved to scraped_content/target2687.txt
#       -> Scraping: https://www.gov.uk/disciplinary-procedures-and-action-at-work
#         -> Saved to scraped_content/target2688.txt
#       -> Scraping: https://www.gov.uk/dismissal
#         -> Saved to scraped_content/target2689.txt
#       -> Scraping: https://www.gov.uk/handing-in-your-notice
#         -> Saved to scraped_content/target2690.txt
#       -> Scraping: https://www.gov.uk/lay-offs-short-timeworking
#         -> Saved to scraped_content/target2691.txt
#       -> Scraping: https://www.gov.uk/employment-tribunals
#         -> Saved to scraped_content/target2692.txt
#       -> Scraping: https://www.gov.uk/raise-grievance-at-work
#         -> Saved to scraped_content/target2693.txt
#       -> Scraping: https://www.gov.uk/redundancy-payments-helpline
#         -> Saved to scraped_content/target2694.txt
#       -> Scraping: https://www.gov.uk/redundancy-your-rights
#         -> Saved to scraped_content/target2695.txt
#       -> Scraping: https://www.gov.uk/solve-workplace-dispute
#         -> Saved to scraped_content/target2696.txt
#       -> Scraping: https://www.gov.uk/whistleblowing
#         -> Saved to scraped_content/target2697.txt
#       -> Scraping: https://www.gov.uk/your-rights-if-your-employer-is-insolvent
#         -> Saved to scraped_content/target2698.txt
#   -> Processing Sub-Topic: State Pension
#     -> Found 16 content pages (using selector: 'main ul.govuk-list a[href]')
#       -> Scraping: https://www.gov.uk/new-state-pension
#         -> Saved to scraped_content/target2699.txt
#       -> Scraping: https://www.gov.uk/state-pension
#         -> Saved to scraped_content/target2700.txt
#       -> Scraping: https://www.gov.uk/additional-state-pension
#         -> Saved to scraped_content/target2701.txt
#       -> Scraping: https://www.gov.uk/state-pension-age
#         -> Saved to scraped_content/target2702.txt
#       -> Scraping: https://www.gov.uk/check-state-pension
#         -> Saved to scraped_content/target2703.txt
#       -> Scraping: https://www.gov.uk/deferring-state-pension
#         -> Saved to scraped_content/target2704.txt
#       -> Scraping: https://www.gov.uk/plan-for-retirement
#         -> Saved to scraped_content/target2705.txt
#       -> Scraping: https://www.gov.uk/over-80-pension
#         -> Saved to scraped_content/target2706.txt
#       -> Scraping: https://www.gov.uk/get-state-pension
#         -> Saved to scraped_content/target2707.txt
#       -> Scraping: https://www.gov.uk/state-pension-if-you-retire-abroad
#         -> Saved to scraped_content/target2708.txt
#       -> Scraping: https://www.gov.uk/contact-pension-service
#         -> Saved to scraped_content/target2709.txt
#       -> Scraping: https://www.gov.uk/international-pension-centre
#         -> Saved to scraped_content/target2710.txt
#       -> Scraping: https://www.gov.uk/future-pension-centre
#         -> Saved to scraped_content/target2711.txt
#       -> Scraping: https://www.gov.uk/apply-for-elderly-person-bus-pass
#         -> Saved to scraped_content/target2712.txt
#       -> Scraping: https://www.gov.uk/pension-credit
#         -> Saved to scraped_content/target2713.txt
#       -> Scraping: https://www.gov.uk/winter-fuel-payment
#         -> Saved to scraped_content/target2714.txt
#   -> Processing Sub-Topic: Workplace and personal pensions
#     -> Found 16 content pages (using selector: 'main ul.govuk-list a[href]')
#       -> Scraping: https://www.gov.uk/early-retirement-pension
#         -> Saved to scraped_content/target2715.txt
#       -> Scraping: https://www.gov.uk/armed-forces-pension-calculator
#         -> Saved to scraped_content/target2716.txt
#       -> Scraping: https://www.gov.uk/find-pension-contact-details
#         -> Saved to scraped_content/target2717.txt
#       -> Scraping: https://www.gov.uk/pension-credit
#         -> Saved to scraped_content/target2718.txt
#       -> Scraping: https://www.gov.uk/pension-credit-calculator
#         -> Saved to scraped_content/target2719.txt
#       -> Scraping: https://www.gov.uk/personal-pensions-your-rights
#         -> Saved to scraped_content/target2720.txt
#       -> Scraping: https://www.gov.uk/plan-retirement-income
#         -> Saved to scraped_content/target2721.txt
#       -> Scraping: https://www.gov.uk/plan-for-retirement
#         -> Saved to scraped_content/target2722.txt
#       -> Scraping: https://www.gov.uk/tax-on-pension-death-benefits
#         -> Saved to scraped_content/target2723.txt
#       -> Scraping: https://www.gov.uk/tax-on-your-private-pension
#         -> Saved to scraped_content/target2724.txt
#       -> Scraping: https://www.gov.uk/tax-on-pension
#         -> Saved to scraped_content/target2725.txt
#       -> Scraping: https://www.gov.uk/transferring-your-pension
#         -> Saved to scraped_content/target2726.txt
#       -> Scraping: https://www.gov.uk/pension-types
#         -> Saved to scraped_content/target2727.txt
#       -> Scraping: https://www.gov.uk/war-pension-armed-forces-compensation-tribunal
#         -> Saved to scraped_content/target2728.txt
#       -> Scraping: https://www.gov.uk/workplace-pensions
#         -> Saved to scraped_content/target2729.txt
#       -> Scraping: https://www.gov.uk/employers-workplace-pensions-rules
#         -> Saved to scraped_content/target2730.txt
#   -> Processing Sub-Topic: Your contract and working hours
#     -> Found 17 content pages (using selector: 'main ul.govuk-list a[href]')
#       -> Scraping: https://www.gov.uk/your-employment-contract-how-it-can-be-changed
#         -> Saved to scraped_content/target2731.txt
#       -> Scraping: https://www.gov.uk/what-is-the-construction-industry-scheme
#         -> Saved to scraped_content/target2732.txt
#       -> Scraping: https://www.gov.uk/continuous-employment-what-it-is
#         -> Saved to scraped_content/target2733.txt
#       -> Scraping: https://www.gov.uk/employer-relocation-your-rights
#         -> Saved to scraped_content/target2734.txt
#       -> Scraping: https://www.gov.uk/au-pairs-employment-law
#         -> Saved to scraped_content/target2735.txt
#       -> Scraping: https://www.gov.uk/employment-contracts-and-conditions
#         -> Saved to scraped_content/target2736.txt
#       -> Scraping: https://www.gov.uk/employment-status
#         -> Saved to scraped_content/target2737.txt
#       -> Scraping: https://www.gov.uk/find-gender-pay-gap-data
#         -> Saved to scraped_content/target2738.txt
#       -> Scraping: https://www.gov.uk/fixed-term-contracts
#         -> Saved to scraped_content/target2739.txt
#       -> Scraping: https://www.gov.uk/flexible-working
#         -> Saved to scraped_content/target2740.txt
#       -> Scraping: https://www.gov.uk/maximum-weekly-working-hours
#         -> Saved to scraped_content/target2741.txt
#       -> Scraping: https://www.gov.uk/night-working-hours
#         -> Saved to scraped_content/target2742.txt
#       -> Scraping: https://www.gov.uk/overtime-your-rights
#         -> Saved to scraped_content/target2743.txt
#       -> Scraping: https://www.gov.uk/rest-breaks-work
#         -> Saved to scraped_content/target2744.txt
#       -> Scraping: https://www.gov.uk/sunday-working
#         -> Saved to scraped_content/target2745.txt
#       -> Scraping: https://www.gov.uk/workplace-bullying-and-harassment
#         -> Saved to scraped_content/target2746.txt
#       -> Scraping: https://www.gov.uk/agency-workers-your-rights
#         -> Saved to scraped_content/target2747.txt
#   -> Processing Sub-Topic: Your pay, tax and the National Minimum Wage
#     -> Found 15 content pages (using selector: 'main ul.govuk-list a[href]')
#       -> Scraping: https://www.gov.uk/keeping-your-pay-tax-records
#         -> Saved to scraped_content/target2748.txt
#       -> Scraping: https://www.gov.uk/national-insurance
#         -> Saved to scraped_content/target2749.txt
#       -> Scraping: https://www.gov.uk/am-i-getting-minimum-wage
#         -> Saved to scraped_content/target2750.txt
#       -> Scraping: https://www.gov.uk/national-minimum-wage-accommodation
#         -> Saved to scraped_content/target2751.txt
#       -> Scraping: https://www.gov.uk/national-minimum-wage-rates
#         -> Saved to scraped_content/target2752.txt
#       -> Scraping: https://www.gov.uk/paye-forms-p45-p60-p11d
#         -> Saved to scraped_content/target2753.txt
#       -> Scraping: https://www.gov.uk/pay-and-work-rights
#         -> Saved to scraped_content/target2754.txt
#       -> Scraping: https://www.gov.uk/payslips
#         -> Saved to scraped_content/target2755.txt
#       -> Scraping: https://www.gov.uk/student-jobs-paying-tax
#         -> Saved to scraped_content/target2756.txt
#       -> Scraping: https://www.gov.uk/tax-company-benefits
#         -> Saved to scraped_content/target2757.txt
#       -> Scraping: https://www.gov.uk/termination-payments-and-tax-when-you-leave-a-job
#         -> Saved to scraped_content/target2758.txt
#       -> Scraping: https://www.gov.uk/national-minimum-wage
#         -> Saved to scraped_content/target2759.txt
#       -> Scraping: https://www.gov.uk/tips-at-work
#         -> Saved to scraped_content/target2760.txt
#       -> Scraping: https://www.gov.uk/understanding-your-pay
#         -> Saved to scraped_content/target2761.txt
#       -> Scraping: https://www.gov.uk/working-abroad
#         -> Saved to scraped_content/target2762.txt
#   -> Processing Sub-Topic: Your rights at work and trade unions
#     -> Found 20 content pages (using selector: 'main ul.govuk-list a[href]')
#       -> Scraping: https://www.gov.uk/agricultural-workers-rights
#         -> Saved to scraped_content/target2763.txt
#       -> Scraping: https://www.gov.uk/monitoring-work-workers-rights
#         -> Saved to scraped_content/target2764.txt
#       -> Scraping: https://www.gov.uk/complain-trade-union
#         -> Saved to scraped_content/target2765.txt
#       -> Scraping: https://www.gov.uk/discrimination-your-rights
#         -> Saved to scraped_content/target2766.txt
#       -> Scraping: https://www.gov.uk/equality-advisory-support-service
#         -> Saved to scraped_content/target2767.txt
#       -> Scraping: https://www.gov.uk/informing-consulting-employees-law
#         -> Saved to scraped_content/target2768.txt
#       -> Scraping: https://www.gov.uk/join-trade-union
#         -> Saved to scraped_content/target2769.txt
#       -> Scraping: https://www.gov.uk/personal-data-my-employer-can-keep-about-me
#         -> Saved to scraped_content/target2770.txt
#       -> Scraping: https://www.gov.uk/working-when-pregnant-your-rights
#         -> Saved to scraped_content/target2771.txt
#       -> Scraping: https://www.gov.uk/reasonable-adjustments-for-disabled-workers
#         -> Saved to scraped_content/target2772.txt
#       -> Scraping: https://www.gov.uk/request-information-consultation-agreement
#         -> Saved to scraped_content/target2773.txt
#       -> Scraping: https://www.gov.uk/stopping-industrial-action-citizens-rights
#         -> Saved to scraped_content/target2774.txt
#       -> Scraping: https://www.gov.uk/medical-suspensions-from-work
#         -> Saved to scraped_content/target2775.txt
#       -> Scraping: https://www.gov.uk/industrial-action-strikes
#         -> Saved to scraped_content/target2776.txt
#       -> Scraping: https://www.gov.uk/rights-of-trade-union-reps
#         -> Saved to scraped_content/target2777.txt
#       -> Scraping: https://www.gov.uk/training-study-work-your-rights
#         -> Saved to scraped_content/target2778.txt
#       -> Scraping: https://www.gov.uk/working-abroad
#         -> Saved to scraped_content/target2779.txt
#       -> Scraping: https://www.gov.uk/working-retirement-pension-age
#         -> Saved to scraped_content/target2780.txt
#       -> Scraping: https://www.gov.uk/workplace-bullying-and-harassment
#         -> Saved to scraped_content/target2781.txt
#       -> Scraping: https://www.gov.uk/workplace-temperatures
#         -> Saved to scraped_content/target2782.txt
# --------------------------------------------------
#
# Scraping complete. Total files saved: 2782 in the 'scraped_content' directory.
